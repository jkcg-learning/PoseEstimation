# %% [markdown]
# <a href="https://colab.research.google.com/github/jkcg-learning/PoseEstimation/blob/main/PoseKeypoints_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Blazepose Keypoints (33)
# https://github.com/tensorflow/tfjs-models/tree/master/pose-detection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Movenet COCO Keypoints (17)
#
# Algorithms by different repos have a different numbering on COCO keypoints
#
# https://github.com/tensorflow/tfjs-models/tree/master/pose-detection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # OpenPose COCO keypoint(18)
# https://cmu-perceptual-computing-lab.github.io/openpose/web/html/doc/md_doc_02_output.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # OpenPose Body(25)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Alpha Pose (26 keypoint)
#
# https://github.com/Fang-Haoshu/Halpe-FullBody

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # VIBE ( 49 keypoints to 25 keypoints)
#
# https://github.com/skelemoa/quovadis/issues/7
#
# https://github.com/mkocabas/VIBE/blob/master/lib/data_utils/kp_utils.py#L212

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dataset NTU-120 and NTU-60 (25 keypoint) representation
#
# https://www.researchgate.net/figure/a-The-joint-labeling-of-the-NTU-RGBD-and-NTU-RGBD-120-datasets-the-21st-node-is_fig1_339425526

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dataset Pennaction (13 keypoints)
#
# http://dreamdragon.github.io/PennAction/
